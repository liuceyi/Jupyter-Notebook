# %%
import seaborn as sns
df=sns.load_dataset('iris')

# %%
sns.violinplot(x=df["species"],y=df["sepal_length"])
# Out:
# <AxesSubplot:xlabel='species', ylabel='sepal_length'>

# %%
import pandas as pd

# %%
df=pd.read_csv(r'./market-cap-by-sector.csv')
df
# Out:
#            sector  marketcap
# 0         telecom         12
# 1         telecom         18
# 2   manufacturing         60
# 3          retail         20
# 4          retail         25
# ..            ...        ...
# 94  manufacturing         62
# 95  manufacturing         67
# 96  manufacturing         58
# 97  manufacturing         57
# 98  manufacturing         60
#
# [99 rows x 2 columns]

# %%
sns.violinplot(x=df["sector"],y=df["marketcap"])
# Out:
# <AxesSubplot:xlabel='sector', ylabel='marketcap'>

# %%
import matplotlib.pyplot as plt

# %%
sns.violinplot(y=df["sector"],x=df["marketcap"])
plt.show()
