# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('bank_train.csv')

# %%
data
# Out:
#        age          job   marital  education default  balance housing loan  \
# 0       29       admin.   married  secondary      no     1489     yes   no
# 1       33       admin.    single   tertiary      no     3379      no   no
# 2       30   management   married   tertiary      no     3134     yes   no
# 3       33       admin.  divorced  secondary      no      294     yes   no
# 4       42   technician   married   tertiary      no      644     yes   no
# ...    ...          ...       ...        ...     ...      ...     ...  ...
# 29382   55    housemaid  divorced    unknown      no     3068      no   no
# 29383   38  blue-collar   married    primary      no     -459     yes  yes
# 29384   52   management   married   tertiary      no     1147      no   no
# 29385   34   technician    single   tertiary     yes       33     yes  yes
# 29386   44   management   married  secondary      no     3286     yes   no
#
#         contact  day month  campaign  pdays  previous poutcome subscribed
# 0      cellular   20   apr         1     -1         0  unknown         no
# 1      cellular   20   nov         3     -1         0  unknown         no
# 2      cellular   17   jul         1     -1         0  unknown         no
# 3      cellular    8   may         1     -1         0  unknown        yes
# 4       unknown    7   may         1     -1         0  unknown         no
# ...         ...  ...   ...       ...    ...       ...      ...        ...
# 29382  cellular    7   jul         3     -1         0  unknown         no
# 29383  cellular   19   nov         2     -1         0  unknown         no
# 29384   unknown   18   jun         1     -1         0  unknown         no
# 29385   unknown    9   may         1     -1         0  unknown         no
# 29386  cellular   18   jul         1     -1         0  unknown         no
#
# [29387 rows x 16 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29387 entries, 0 to 29386
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   age         29387 non-null  int64
#  1   job         29387 non-null  object
#  2   marital     29387 non-null  object
#  3   education   29387 non-null  object
#  4   default     29387 non-null  object
#  5   balance     29387 non-null  int64
#  6   housing     29387 non-null  object
#  7   loan        29387 non-null  object
#  8   contact     29387 non-null  object
#  9   day         29387 non-null  int64
#  10  month       29387 non-null  object
#  11  campaign    29387 non-null  int64
#  12  pdays       29387 non-null  int64
#  13  previous    29387 non-null  int64
#  14  poutcome    29387 non-null  object
#  15  subscribed  29387 non-null  object
# dtypes: int64(6), object(10)
# memory usage: 3.6+ MB

# %%
for i in range(16):
    print(data.columns[i])
    print (data.iloc[:,i].unique(),'\n')
# Out:
# age
# [29 33 30 42 39 27 32 43 55 36 51 57 31 37 35 21 54 53 26 44 49 40 34 58
#  24 59 48 25 47 41 60 45 22 28 56 50 64 23 46 61 52 20 67 38 66 71 95 72
#  83 69 74 70 62 68 77 75 76 78 63 80 73 81 19 65 82 79 87 86 85 18 84 93
#  89 94 88 92 90]
#
# job
# ['admin.' 'management' 'technician' 'entrepreneur' 'self-employed'
#  'services' 'blue-collar' 'retired' 'housemaid' 'unemployed' 'student'
#  'unknown']
#
# marital
# ['married' 'single' 'divorced']
#
# education
# ['secondary' 'tertiary' 'unknown' 'primary']
#
# default
# ['no' 'yes']
#
# balance
# [1489 3379 3134 ... 5958 3969 -144]
#
# housing
# ['yes' 'no']
#
# loan
# ['no' 'yes']
#
# contact
# ['cellular' 'unknown' 'telephone']
#
# day
# [20 17  8  7 16  6  3 15 14  4  9 29 25 19  5 12  2 18 13 21 30 27 31 22
#  11 23  1 28 26 10 24]
#
# month
# ['apr' 'nov' 'jul' 'may' 'jun' 'aug' 'feb' 'jan' 'sep' 'oct' 'mar' 'dec']
#
# campaign
# [ 1  3  6  2  4  5 16 10  8 15  9  7 21 13 11 12 17 14 19 50 55 41 25 29
#  22 18 39 28 23 26 20 32 24 33 30 35 44 31 36 38 43 34 27 63 51 37]
#
# pdays
# [ -1 289 170 117 295  92 217 347 159 353 111 352 264 149 330 208 338  90
#   96 104 183 345 301  80  74 365  70 197 247 201 336  99 368 246 204 156
#  141 178 331 255 286 288 226   8 344 181 186 176 119 167 190 490 191 271
#  260 103 131 189  98 172 281 355 261 148 102 173 254 188 199  65 360 146
#  415  95 207  81 364 266 126 184 304  91 363 193  87 275 356 270 134  12
#  164 486 175 343 311 372 334 241 349 367 132 138 272 348  27 273 366 686
#  154 187  94  88 328 536 206   5 298 346 351 370 137  89 223  28  93 100
#  249 115 341 282 129 362  83 375 174   1  22 225 296   7 479 322 557 358
#  113 262 151  86 169 248 263 105 283 475   6 177 101 192 185  72   2  56
#  166 280 200 299 371 180 251 140 244 342 195 252 214 211 147 123 389 287
#  144 339 163 350 227  77 454 436 333 171 300 268 359 233 314  97 274 118
#   71 212 293 340  14 326  82 110 373 292 265 179 388  84 182 168 302 316
#  124  10  78 357 361 106 116 127 337 374 112 321 250 240 308 269 285 312
#   64 150 541 210 143  63  79 237 291 245 160 109 196 239 133 152 259 276
#  198 294 136 267 511 277 257 107 228 162 202 391 369 626  48   9 553 323
#   85 258 231 492 317 808 213 318 850 229 469 842 230  37 386 419 515 122
#  128 253 354 791 463 279 224 161 377  67 426  76 114 405 153 194 332 452
#  320 158 309 108 480 120  57 297 142 760 205 319 130  68 236 135 761  13
#  446  41 430  33 384 403  31 335 278 428 329 324 464 242 461 449 238 518
#  235 392 155 485  21 310 315 203 409 139 256  20  24  44  42 325 305 307
#   58 327  35 551 514 376  38 393 219 687  26 303 165 390 383  50 455 434
#   59 385 157 215 284  60 465 412  40 831 433  62 683 457 243 313  29 779
#  397 232 416 500 234 792 414 398 521  53 586 460 805 555  55  75  66 432
#  462  30  25 524 290  52 784 306 145 379 209 474 440 491  17 387  43 532
#  221 378 417 561  49 421 478  32  36  73 216 503 670 550  15 603 828 717
#  381 579 121 382  46 749 125  19 424 701  61 489 222 667 544   4 854 410
#  431 543 690 399 220 407 756 651 838 422 472 458 420  39 444 594 218 450
#  520 401 826 442 504 425 648 578 439 508 394 477 435 745 530 411 456]
#
# previous
# [ 0  4  1  8  2  3  9  5 24 20  7 11 10 18  6 15 32 27 12 17 16 14 13 29
#  38 23 19 28 30 22 25 35 26 21 37]
#
# poutcome
# ['unknown' 'failure' 'success' 'other']
#
# subscribed
# ['no' 'yes']

# %%
data.isnull()
# Out:
#          age    job  marital  education  default  balance  housing   loan  \
# 0      False  False    False      False    False    False    False  False
# 1      False  False    False      False    False    False    False  False
# 2      False  False    False      False    False    False    False  False
# 3      False  False    False      False    False    False    False  False
# 4      False  False    False      False    False    False    False  False
# ...      ...    ...      ...        ...      ...      ...      ...    ...
# 29382  False  False    False      False    False    False    False  False
# 29383  False  False    False      False    False    False    False  False
# 29384  False  False    False      False    False    False    False  False
# 29385  False  False    False      False    False    False    False  False
# 29386  False  False    False      False    False    False    False  False
#
#        contact    day  month  campaign  pdays  previous  poutcome  subscribed
# 0        False  False  False     False  False     False     False       False
# 1        False  False  False     False  False     False     False       False
# 2        False  False  False     False  False     False     False       False
# 3        False  False  False     False  False     False     False       False
# 4        False  False  False     False  False     False     False       False
# ...        ...    ...    ...       ...    ...       ...       ...         ...
# 29382    False  False  False     False  False     False     False       False
# 29383    False  False  False     False  False     False     False       False
# 29384    False  False  False     False  False     False     False       False
# 29385    False  False  False     False  False     False     False       False
# 29386    False  False  False     False  False     False     False       False
#
# [29387 rows x 16 columns]

# %% [markdown]
# ## EDA

# %%
data['subscribed'] = data['subscribed'].map({'no':0,'yes':1})

# %%
data.head()
# Out:
#    age         job   marital  education default  balance housing loan  \
# 0   29      admin.   married  secondary      no     1489     yes   no
# 1   33      admin.    single   tertiary      no     3379      no   no
# 2   30  management   married   tertiary      no     3134     yes   no
# 3   33      admin.  divorced  secondary      no      294     yes   no
# 4   42  technician   married   tertiary      no      644     yes   no
#
#     contact  day month  campaign  pdays  previous poutcome  subscribed
# 0  cellular   20   apr         1     -1         0  unknown           0
# 1  cellular   20   nov         3     -1         0  unknown           0
# 2  cellular   17   jul         1     -1         0  unknown           0
# 3  cellular    8   may         1     -1         0  unknown           1
# 4   unknown    7   may         1     -1         0  unknown           0

# %%
def pct(category,value):
    temp = data[data[category] == value]['subscribed']
    temp_ys = sum(temp)
    temp_ns = len(temp) - temp_ys
    temp_r = temp_ys/len(temp)
    temp_array = np.array((temp_ys,temp_ns,temp_r))
    return(temp_array)

# %% [markdown]
# ### Age

# %%
category  = 'age'

# %%
age = data[category].sort_values().unique()
data_info = pd.DataFrame(columns = ['category', 'value', 'yes', 'no', 'pct'])

for value in age:
    temp = [category,value]
    temp_array = pct(category, value)
    temp.append(temp_array[0])
    temp.append(temp_array[1])
    temp.append(temp_array[2])
    temp = pd.Series(temp, index=['category', 'value', 'yes', 'no', 'pct'])
    data_info = data_info.append(temp, ignore_index = True)

# %%
data_info
# Out:
#    category value   yes    no       pct
# 0       age    18   5.0   3.0  0.625000
# 1       age    19   5.0  13.0  0.277778
# 2       age    20  11.0  22.0  0.333333
# 3       age    21  19.0  40.0  0.322034
# 4       age    22  25.0  65.0  0.277778
# ..      ...   ...   ...   ...       ...
# 72      age    90   1.0   0.0  1.000000
# 73      age    92   1.0   0.0  1.000000
# 74      age    93   1.0   0.0  1.000000
# 75      age    94   0.0   1.0  0.000000
# 76      age    95   1.0   0.0  1.000000
#
# [77 rows x 5 columns]

# %%
plt.figure(figsize = (10,5))
plt.plot(data_info['value'],data_info['pct'])
plt.show()

# %%
plt.figure(figsize = (10,5))
plt.bar(range(len(age))+age[0],height = data_info['no'], label = 'no')
plt.bar(range(len(age))+age[0],height = data_info['yes'], bottom = data_info['no'], label = 'yes')
plt.plot(data_info['value'],data_info['pct']*1000,'o-',color = 'r', label = 'positive rate')
plt.xlabel('Age')
plt.legend()
plt.show()

# %% [markdown]
# ### Job

# %%
category  = 'job'

# %%
job = data[category].sort_values().unique()
data_info = pd.DataFrame(columns = ['category', 'value', 'yes', 'no', 'pct'])

for value in job:
    temp = [category,value]
    temp_array = pct(category, value)
    temp.append(temp_array[0])
    temp.append(temp_array[1])
    temp.append(temp_array[2])
    temp = pd.Series(temp, index=['category', 'value', 'yes', 'no', 'pct'])
    data_info = data_info.append(temp, ignore_index = True)

# %%
data_info
# Out:
#    category          value    yes      no       pct
# 0       job         admin.  413.0  2979.0  0.121757
# 1       job    blue-collar  451.0  5891.0  0.071113
# 2       job   entrepreneur   91.0   862.0  0.095488
# 3       job      housemaid   73.0   738.0  0.090012
# 4       job     management  846.0  5258.0  0.138598
# 5       job        retired  345.0  1142.0  0.232011
# 6       job  self-employed  119.0   894.0  0.117473
# 7       job       services  242.0  2460.0  0.089563
# 8       job        student  174.0   431.0  0.287603
# 9       job     technician  538.0  4415.0  0.108621
# 10      job     unemployed  127.0   709.0  0.151914
# 11      job        unknown   19.0   170.0  0.100529

# %%
data_info = data_info.sort_values(by='pct')

# %%
plt.figure(figsize = (10,5))
plt.bar(range(len(job)),height = data_info['no'], label = 'no')
plt.bar(range(len(job)),height = data_info['yes'], bottom = data_info['no'], label = 'yes')
plt.plot(data_info['value'],data_info['pct']*10000,'o-',color = 'r', label = 'positive rate')
plt.xlabel('job')
plt.xticks(rotation = -45)
plt.legend()
plt.show()

# %% [markdown]
# ### marital

# %%
category  = 'marital'

# %%
marital = data[category].sort_values().unique()
data_info = pd.DataFrame(columns = ['category', 'value', 'yes', 'no', 'pct'])

for value in marital:
    temp = [category,value]
    temp_array = pct(category, value)
    temp.append(temp_array[0])
    temp.append(temp_array[1])
    temp.append(temp_array[2])
    temp = pd.Series(temp, index=['category', 'value', 'yes', 'no', 'pct'])
    data_info = data_info.append(temp, ignore_index = True)

# %%
data_info
# Out:
#   category     value     yes       no       pct
# 0  marital  divorced   413.0   3006.0  0.120796
# 1  marital   married  1800.0  15774.0  0.102424
# 2  marital    single  1225.0   7169.0  0.145938

# %%
data_info = data_info.sort_values(by='pct')

# %%
plt.figure(figsize = (10,5))
plt.bar(range(len(marital)),height = data_info['no'], label = 'no')
plt.bar(range(len(marital)),height = data_info['yes'], bottom = data_info['no'], label = 'yes')
plt.plot(data_info['value'],data_info['pct']*100000,'o-',color = 'r', label = 'positive rate')
plt.xlabel(category)
plt.xticks(rotation = -45)
plt.legend()
plt.show()

# %% [markdown]
# ## Education

# %%
category  = 'education'

# %%
education = data[category].sort_values().unique()
data_info = pd.DataFrame(columns = ['category', 'value', 'yes', 'no', 'pct'])

for value in education:
    temp = [category,value]
    temp_array = pct(category, value)
    temp.append(temp_array[0])
    temp.append(temp_array[1])
    temp.append(temp_array[2])
    temp = pd.Series(temp, index=['category', 'value', 'yes', 'no', 'pct'])
    data_info = data_info.append(temp, ignore_index = True)

# %%
data_info
# Out:
#     category      value     yes       no       pct
# 0  education    primary   387.0   4069.0  0.086849
# 1  education  secondary  1588.0  13515.0  0.105145
# 2  education   tertiary  1301.0   7338.0  0.150596
# 3  education    unknown   162.0   1027.0  0.136249

# %%
plt.figure(figsize = (10,5))
plt.bar(range(len(education)),height = data_info['no'], label = 'no')
plt.bar(range(len(education)),height = data_info['yes'], bottom = data_info['no'], label = 'yes')
plt.plot(data_info['value'],data_info['pct']*100000,'o-',color = 'r', label = 'positive rate')
plt.xlabel('education')
plt.xticks(rotation = -45)
plt.legend()
plt.show()
