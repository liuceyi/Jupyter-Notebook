# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
sns.set(style="darkgrid")
df=sns.load_dataset("iris")
sns
# Out:
# <module 'seaborn' from 'G:\\Programming\\Python\\Anaconda\\lib\\site-packages\\seaborn\\__init__.py'>

# %%
sns.histplot(data=df,x="sepal_length")
plt.show()

# %%
sns.histplot(data=df,x="sepal_length",kde=True)
plt.show()

# %%
sns.histplot(data=df,x="sepal_length",bins=50)
plt.show()

# %%
df=pd.read_csv(r'./market-cap-by-sector.csv')
sns.histplot(data=df,x="marketcap")
plt.show()

# %%
sns.histplot(data=df,x="marketcap",kde=True)
plt.show()

# %%
sns.histplot(data=df,x="marketcap",bins=20)
plt.show()

# %%
sns.histplot(data=df,x="marketcap",bins=20, kde=True)
plt.show()
