# %%
import requests
from bs4 import BeautifulSoup
import re
import pandas as pd

# Send request & Load the page
headers = {
  'user-agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/92.0.4515.131 Safari/537.36'
}
url = 'https://www.amazon.com/Best-Sellers-Kindle-Store/zgbs/digital-text'
content = requests.get(url, headers=headers).text
soup = BeautifulSoup(content, 'html.parser')

# Load each card
cards = soup.select('.zg-item-immersion')
cards_arr = []
for card in cards:
  card_obj = {}
  # Handle title
  title_html = card.select('.p13n-sc-truncate')[0]
  title = title_html.text.strip()
  title = re.sub(u"\\(.*?\\)", "", title)
  card_obj['title'] = title

  # Handle author 

  author_html = card.select('.a-link-child')
  if len(author_html) > 0:
    author = author_html[0].text.strip()
    card_obj['author'] = author
  
  
    
  # Handle rating
  try:
    rate_html = card.select('.a-icon-alt')[0]
    rate = rate_html.text
    rate = re.sub(r" out of.*?$", "", rate)
    card_obj['rate'] = float(rate)
  except Exception as e:
    # print(e)
    pass
  


  # Handle rank
  rank_html = card.select('.zg-badge-text')[0]
  rank = rank_html.text
  card_obj['rank'] = rank.strip('#')

  # Handle price
  price_html = card.select('.p13n-sc-price')[0]
  price = price_html.text.strip('$')
  card_obj['price'] = float(price)
  
  cards_arr.append(card_obj)

cards_pd = pd.DataFrame(cards_arr)
cards_pd
# Out:
#                                                 title               author  \
# 0                                               Peril         Bob Woodward
# 1                                   Apples Never Fall       Liane Moriarty
# 2                         The Keeper of Happy Endings        Barbara Davis
# 3   The Lost Continent: Travels in Small Town America          Bill Bryson
# 4   Change the Story, Save the World: Efficiency I...     Moritz Davidesko
# 5   The Child in the Photo: An absolutely addictiv...      Kerry Wilkinson
# 6                                   Right Behind Her         Melinda Leigh
# 7                                       The Casanova              T L Swan
# 8   If You Tell: A True Story of Murder, Family Se...          Gregg Olsen
# 9                         What's Left Unsaid: A Novel        Emily Bleeker
# 10                                       Fated Blades                  NaN
# 11                                Enemy at the Gates                   NaN
# 12        Perfect Grump: An Enemies to Lovers Romance          Nicole Snow
# 13                       Misjudged: A Legal Thriller        James Chandler
# 14                   The Wrong Game: A Sports Romance        Kandi Steiner
# 15                              Good as Dead: A Novel         Susan Walter
# 16                 The Lie : a bad boy sports romance       Karla Sorensen
# 17                                      The Stopover              T L Swan
# 18                                The Moonlight Child     Karen McQuestion
# 19                 The Last Thing He Told Me: A Novel           Laura Dave
# 20  Give Me a Reason: A Single Dad, Enemies-to-Lov...         A.L. Jackson
# 21                                      Hornet Flight          Ken Follett
# 22                                     The Chaos Kind         Barry Eisler
# 23                                             Verity       Colleen Hoover
# 24  Brand Hacks: How to Build Brands by Fulfilling...                  NaN
# 25                                           Piranesi       Susanna Clarke
# 26                                 The Highland Fling         Meghan Quinn
# 27                                The Best of Friends        Lucinda Berry
# 28                            American Dirt : A Novel      Jeanine Cummins
# 29                                   Hostage: A Novel     Clare Mackintosh
# 30                                        Dirty Curve        Meagan Brandy
# 31                          The Judge's List: A Novel         John Grisham
# 32                              The Girl in Cabin 13           A.J. Rivers
# 33                                             Drift             L.T. Ryan
# 34            Forgotten in Death: An Eve Dallas Novel           J. D. Robb
# 35                      The Last Anniversary: A Novel       Liane Moriarty
# 36              Harry Potter and the Sorcerer's Stone         J.K. Rowling
# 37                      The Midnight Library: A Novel            Matt Haig
# 38                                      Moon Touched      Elizabeth Briggs
# 39                                 Truly Madly Guilty       Liane Moriarty
# 40                            Harlem Shuffle: A Novel     Colson Whitehead
# 41                                     Savage Prince            S. Massery
# 42                                      The Takeover              T L Swan
# 43  A History of God: The 4,000-Year Quest of Juda...      Karen Armstrong
# 44                         Promises and Pomegranates         Sav R. Miller
# 45           Miss Graham's Cold War Cookbook: A Novel           Celia Rees
# 46                                The Love Hypothesis        Ali Hazelwood
# 47                                  Every Last Secret          A. R. Torre
# 48                                 Eaters of the Dead     Michael Crichton
# 49                     These Toxic Things: A Thriller  Rachel Howzell Hall
#
#    rank  price  rate
# 0     1  14.99   NaN
# 1     2  14.99   4.4
# 2     3   4.99   4.7
# 3     4   1.99   4.0
# 4     5   0.99   4.9
# 5     6   0.99   4.3
# 6     7   6.99   4.7
# 7     8   3.99   4.7
# 8     9   2.99   4.4
# 9    10   1.99   4.3
# 10   11   3.99   NaN
# 11   12  14.99   4.7
# 12   13   2.99   4.4
# 13   14   4.99   4.3
# 14   15   4.99   4.4
# 15   16   4.99   4.4
# 16   17   4.99   4.8
# 17   18   3.99   4.6
# 18   19   4.99   4.4
# 19   20  13.99   4.3
# 20   21   3.99   4.5
# 21   22   1.99   4.5
# 22   23   4.99   4.5
# 23   24   5.99   4.6
# 24   25   0.99   5.0
# 25   26   4.99   4.5
# 26   27   4.99   4.5
# 27   28   4.99   4.3
# 28   29  14.99   4.6
# 29   30   1.99   4.3
# 30   31   4.99   4.7
# 31   32  14.99   NaN
# 32   33   4.99   4.3
# 33   34   4.99   4.4
# 34   35  14.99   4.8
# 35   36  10.99   4.2
# 36   37   9.99   4.8
# 37   38  10.99   4.4
# 38   39   3.99   4.6
# 39   40   9.99   3.9
# 40   41  14.99   4.0
# 41   42   4.99   4.8
# 42   43   3.99   4.7
# 43   44   2.99   4.5
# 44   45   4.99   4.3
# 45   46   1.99   4.3
# 46   47   9.99   4.8
# 47   48   4.99   4.3
# 48   49   1.99   4.5
# 49   50   4.99   4.1

# %%
cards_pd[(cards_pd['rate'] > 4.5) & (cards_pd['price'] == 4.99)]
# Out:
#                                  title rank  price  rate
# 2          The Keeper of Happy Endings   #3   4.99   4.7
# 16  The Lie : a bad boy sports romance  #17   4.99   4.8
# 30                         Dirty Curve  #31   4.99   4.7
# 41                      Savage Prince   #42   4.99   4.8

# %%
cards_pd.to_csv("A2_books.csv",index=False,sep=',')
